# %%
import os
os.chdir(r'C:\algo2')
# coding=utf-8
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import pytz
import datetime
from Utils import Utils
from IBridgePy.IbridgepyTools import symbol
from configuration import test_me
from data_provider_factory.data_loading_plan import HistIngestionPlan, Plan
import pandas as pd

# Related YouTube tutorials about IBridgePy backtester
# Build “Buy low Sell high” strategy by Machine learning https://youtu.be/hNCwNxeXrwA
# Detailed explanation about “Buy low Sell high” strategy https://youtu.be/PI5dhqCAuvA
# Calculate Sharpe Ratio https://youtu.be/4xTHdzAMhcI
# Backtest without hist ingestion https://youtu.be/bwmx5hiSPV4
# Backtest with hist ingestion https://youtu.be/XnpxAVU4ogY
# Backtest with hist from local files https://youtu.be/UR_7_F8wPL0
# Speed up backtest by designating spot times https://youtu.be/bVE59nZ02ig
# Convert hist data format https://youtu.be/hYL6SYgy7wE
# Backtest using IBridgePy data center https://youtu.be/0FPgtmUpTI0
fileName = 'UpdatedAlgoCommon.py'
# fileName = 'unitTests.py'
accountCode = 'DU2628075'

dataProviderName = 'IB'  # RANDOM, IB, LOCAL_FILE, TD, ROBINHOOD, IBRIDGEPY

# "histIngestionPlan" is a reserved word in IBridgePy to store the historical data ingestion plan that describes what historical data
# are needed during backtesting and IBridgePy backtester will fetch these data before backtesting to speed up the whole backtesting process.
# "histIngestionPlan" is not required for backtesting but it will make backtest much faster.
# "histIngestionPlan" is an instance of HistIngestionPlan.
histIngestionPlan = HistIngestionPlan()
histIngestionPlan.add(Plan(security=symbol('SPY'), barSize='1 min', goBack='7 D'))

# endTime = dt.datetime.now()
# startTime = endTime - dt.timedelta(days=4)

startTime = dt.datetime(2022,12,13,9,30,0)
endTime = dt.datetime(2022,12,13,16,0,0)

# endTime=endTime-dt.timedelta(days=3)
# As a demo, startTime is 10 days ago from the current time.

# freq = '1H' # 1S = 1 second; 1T = 1 minute; 1H = 1 hour

test_me(fileName, globals())

print("done\ndone\ndone\ndone\ndone\ndone\ndone\ndone\ndone\ndone\ndone\n")
# Out:
# Try brokerClient IB port=7496
# port=7496 is correct and set port to userConfig.brokerClientConfig.IB_CLIENT
# Connected to IB is successful using port=7496
# Backtester ignores order.tif=DAY and handles them as order.tif=GTC. We are working on this feature.
# Simulate trading commission by settings.py --> BACKTESTER --> simulateCommission
# IBridgePy has reset the TRADER.runMode to RUN_LIKE_QUANTOPIAN for backtesting to save time!
# IBridgePy has reset projectConfig.repBarFreq to 60 for backtesting!
# ####     Data ingestion starts    ####
# ingested hist of security=STK,,,SPY,USD barSize=1 min from IB
# 1st line=2022-12-08 14:30:00-05:00
# last line=2022-12-16 20:59:00-05:00
# ####     Data ingestion COMPLETED    ####
# IBridgePy version 18.1.7
# fileName = UpdatedAlgoCommon.py
# ####    Starting to initialize trader    ####
# ##    ACCOUNT Balance  DU2628075  ##
# CASH=100000.0
# portfolio_value=100000.0
# positions_value=0.0
# ##    NO ANY POSITION    ##
# ##    NO any order    ##
# ####    Initialize trader COMPLETED    ####
# Time: 2022-12-13 09:30:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:31:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:32:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:33:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:34:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:35:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:36:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:37:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:38:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:39:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:40:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:41:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:42:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:43:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:44:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:45:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:46:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:47:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:48:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:49:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:50:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:51:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:52:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:53:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:54:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:55:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:56:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:57:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:58:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 09:59:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# Time: 2022-12-13 10:00:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 1.42, 1.74, 0.1
# Time: 2022-12-13 10:01:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:02:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:03:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:04:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:05:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:06:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:07:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:08:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:09:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:10:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.28, 0.75, 0.1
# Time: 2022-12-13 10:11:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:12:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:13:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:14:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:15:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:16:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:17:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:18:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:19:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:20:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:21:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:22:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:23:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:24:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:25:00-05:00
# Position Size:0
# Portfolio Value: 100000.0
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.68, -0.48, 0.1
# We passed the chop, buy short
# checking long
#
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 10:25:00-05:00 62 STK,,,SPY,USD SLD 49 405.79
# Time: 2022-12-13 10:26:00-05:00
# Position Size:-49
# Portfolio Value: 100021.54000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:27:00-05:00
# Position Size:-49
# Portfolio Value: 99999.0
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:28:00-05:00
# Position Size:-49
# Portfolio Value: 100005.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:29:00-05:00
# Position Size:-49
# Portfolio Value: 100017.13
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:30:00-05:00
# Position Size:-49
# Portfolio Value: 100014.19
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:31:00-05:00
# Position Size:-49
# Portfolio Value: 100034.77
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:32:00-05:00
# Position Size:-49
# Portfolio Value: 100045.06
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:33:00-05:00
# Position Size:-49
# Portfolio Value: 100025.95000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 10:34:00-05:00
# Position Size:-49
# Portfolio Value: 99991.65000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 0.0
# Time: 2022-12-13 10:35:00-05:00
# Position Size:-49
# Portfolio Value: 99982.34000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 60.0
# checking double or nothing
# exit not double
# Placing sell order
# Deduct commission=1.0
# 2022-12-13 10:35:00-05:00 74 STK,,,SPY,USD BOT 49 406.13
# Time: 2022-12-13 10:36:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:37:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.55, -0.71, 0.1
# checking long
#
# Time: 2022-12-13 10:38:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.61, -0.71, 0.1
# checking long
#
# Time: 2022-12-13 10:39:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.72, -0.73, 0.1
# checking long
#
# Time: 2022-12-13 10:40:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.74, -0.76, 0.1
# checking long
#
# Time: 2022-12-13 10:41:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.76, -0.78, 0.1
# checking long
#
# Time: 2022-12-13 10:42:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.74, -0.7999999999999999, 0.1
# checking long
#
# Time: 2022-12-13 10:43:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.72, -0.8099999999999999, 0.1
# checking long
#
# Time: 2022-12-13 10:44:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.7, -0.8099999999999999, 0.1
# checking long
#
# Time: 2022-12-13 10:45:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.64, -0.7999999999999999, 0.1
# checking long
#
# Time: 2022-12-13 10:46:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:47:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:48:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:49:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.52, -0.69, 0.1
# checking long
#
# Time: 2022-12-13 10:50:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.49, -0.6699999999999999, 0.1
# checking long
#
# Time: 2022-12-13 10:51:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.46, -0.64, 0.1
# checking long
#
# Time: 2022-12-13 10:52:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.42, -0.62, 0.1
# checking long
#
# Time: 2022-12-13 10:53:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:54:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.4, -0.59, 0.1
# checking long
#
# Time: 2022-12-13 10:55:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.43, -0.58, 0.1
# checking long
#
# Time: 2022-12-13 10:56:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.44, -0.58, 0.1
# checking long
#
# Time: 2022-12-13 10:57:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.42, -0.57, 0.1
# checking long
#
# Time: 2022-12-13 10:58:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 10:59:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.39, -0.55, 0.1
# checking long
#
# Time: 2022-12-13 11:00:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.34, -0.53, 0.1
# checking long
#
# Time: 2022-12-13 11:01:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:02:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:03:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:04:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.2, -0.41000000000000003, 0.1
# checking long
#
# Time: 2022-12-13 11:05:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:06:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:07:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.17, -0.33999999999999997, 0.1
# checking long
#
# Time: 2022-12-13 11:08:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.2, -0.33, 0.1
# checking long
#
# Time: 2022-12-13 11:09:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.17, -0.32, 0.1
# checking long
#
# Time: 2022-12-13 11:10:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:11:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:12:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:13:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:14:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:15:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:16:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:17:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:18:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:19:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:20:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, 0.09, -0.04000000000000001, 0.1
# checking long
#
# Time: 2022-12-13 11:21:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, 0.06, -0.05, 0.1
# checking long
#
# Time: 2022-12-13 11:22:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, 0.01, -0.060000000000000005, 0.1
# checking long
#
# Time: 2022-12-13 11:23:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.02, -0.07, 0.1
# checking long
#
# Time: 2022-12-13 11:24:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.08, -0.1, 0.1
# checking long
#
# Time: 2022-12-13 11:25:00-05:00
# Position Size:0
# Portfolio Value: 99981.34000000001
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.14, -0.13, 0.1
# We passed the chop, buy short
# checking long
#
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 11:25:00-05:00 126 STK,,,SPY,USD SLD 49 404.23
# Time: 2022-12-13 11:26:00-05:00
# Position Size:-49
# Portfolio Value: 99991.12000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:27:00-05:00
# Position Size:-49
# Portfolio Value: 99977.89000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:28:00-05:00
# Position Size:-49
# Portfolio Value: 99971.52000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:29:00-05:00
# Position Size:-49
# Portfolio Value: 99969.56000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:30:00-05:00
# Position Size:-49
# Portfolio Value: 99962.70000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 0.0
# Time: 2022-12-13 11:31:00-05:00
# Position Size:-49
# Portfolio Value: 99943.59000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 60.0
# checking double or nothing
# exit not double
# Placing sell order
# Deduct commission=1.0
# 2022-12-13 11:31:00-05:00 134 STK,,,SPY,USD BOT 49 404.98
# Time: 2022-12-13 11:32:00-05:00
# Position Size:0
# Portfolio Value: 99942.59000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:33:00-05:00
# Position Size:0
# Portfolio Value: 99942.59000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 11:34:00-05:00
# Position Size:0
# Portfolio Value: 99942.59000000001
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.18, 0.15000000000000002, 0.1
# We passed the chop, buy long
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 11:34:00-05:00 139 STK,,,SPY,USD BOT 49 405.33
# Time: 2022-12-13 11:35:00-05:00
# Position Size:49
# Portfolio Value: 99957.76000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:36:00-05:00
# Position Size:49
# Portfolio Value: 99953.84000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 11:37:00-05:00
# Position Size:49
# Portfolio Value: 99927.87000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 0.0
# Time: 2022-12-13 11:38:00-05:00
# Position Size:49
# Portfolio Value: 99924.93000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 60.0
# checking double or nothing
# Double Long
# Deduct commission=1.0
# 2022-12-13 11:38:00-05:00 145 STK,,,SPY,USD BOT 49 404.99
# Time: 2022-12-13 11:39:00-05:00
# Position Size:98
# Portfolio Value: 99940.59000000001
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is:
00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.22, -0.33999999999999997, 0.1
# checking long
#
# Time: 2022-12-13 12:49:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.31, -0.36, 0.1
# checking long
#
# Time: 2022-12-13 12:50:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.39, -0.39, 0.1
# checking long
#
# Time: 2022-12-13 12:51:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.41, -0.41000000000000003, 0.1
# checking long
#
# Time: 2022-12-13 12:52:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.41, -0.43000000000000005, 0.1
# checking long
#
# Time: 2022-12-13 12:53:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.39, -0.44000000000000006, 0.1
# checking long
#
# Time: 2022-12-13 12:54:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.39, -0.44999999999999996, 0.1
# checking long
#
# Time: 2022-12-13 12:55:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.35, -0.44999999999999996, 0.1
# checking long
#
# Time: 2022-12-13 12:56:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 12:57:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 12:58:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 12:59:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:00:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:01:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:02:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.01, -0.26, 0.1
# checking long
#
# Time: 2022-12-13 13:03:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:04:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:05:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:06:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:07:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:08:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:09:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, 0.0, -0.13, 0.1
# checking long
#
# Time: 2022-12-13 13:10:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, 0.01, -0.12000000000000001, 0.1
# checking long
#
# Time: 2022-12-13 13:11:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:12:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:13:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:14:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:15:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:16:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:17:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.2, 0.2, 0.1
# Time: 2022-12-13 13:18:00-05:00
# Position Size:0
# Portfolio Value: 100026.36000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.27, 0.23, 0.1
# We passed the chop, buy long
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 13:18:00-05:00 259 STK,,,SPY,USD BOT 50 401.42
# Time: 2022-12-13 13:19:00-05:00
# Position Size:50
# Portfolio Value: 100027.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:20:00-05:00
# Position Size:50
# Portfolio Value: 100027.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:21:00-05:00
# Position Size:50
# Portfolio Value: 100025.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:22:00-05:00
# Position Size:50
# Portfolio Value: 100031.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:23:00-05:00
# Position Size:50
# Portfolio Value: 100034.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:24:00-05:00
# Position Size:50
# Portfolio Value: 100054.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:25:00-05:00
# Position Size:50
# Portfolio Value: 100052.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:26:00-05:00
# Position Size:50
# Portfolio Value: 100045.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:27:00-05:00
# Position Size:50
# Portfolio Value: 100034.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:28:00-05:00
# Position Size:50
# Portfolio Value: 100041.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:29:00-05:00
# Position Size:50
# Portfolio Value: 100050.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:30:00-05:00
# Position Size:50
# Portfolio Value: 100046.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:31:00-05:00
# Position Size:50
# Portfolio Value: 100070.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:32:00-05:00
# Position Size:50
# Portfolio Value: 100066.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:33:00-05:00
# Position Size:50
# Portfolio Value: 100062.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:34:00-05:00
# Position Size:50
# Portfolio Value: 100058.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 13:35:00-05:00
# Position Size:50
# Portfolio Value: 100034.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 0.0
# Time: 2022-12-13 13:36:00-05:00
# Position Size:50
# Portfolio Value: 100036.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 60.0
# checking double or nothing
# exit not double
# Placing sell order
# Deduct commission=1.0
# 2022-12-13 13:36:00-05:00 279 STK,,,SPY,USD SLD 50 401.65
# Time: 2022-12-13 13:37:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:38:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.28, 0.43000000000000005, 0.1
# Time: 2022-12-13 13:39:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.27, 0.42000000000000004, 0.1
# Time: 2022-12-13 13:40:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:41:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:42:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:43:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:44:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13:45:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.21, 0.33, 0.1
# Time: 2022-12-13 13:46:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.2, 0.32, 0.1
# Time: 2022-12-13 13:47:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.19, 0.32, 0.1
# Time: 2022-12-13 13:48:00-05:00
# Position Size:0
# Portfolio Value: 100035.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 13
86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 14:56:00-05:00
# Position Size:0
# Portfolio Value: 99985.86000000002
# checking the cross
# checking to enter
# checking short
#
# Checking short before the chop
#
# macd and signal with delta, delta, -0.11, 0.0, 0.1
# We passed the chop, buy short
# checking long
#
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 14:56:00-05:00 369 STK,,,SPY,USD SLD 50 401.49
# Time: 2022-12-13 14:57:00-05:00
# Position Size:-50
# Portfolio Value: 100001.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 14:58:00-05:00
# Position Size:-50
# Portfolio Value: 99991.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 14:59:00-05:00
# Position Size:-50
# Portfolio Value: 99984.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:00:00-05:00
# Position Size:-50
# Portfolio Value: 99980.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:01:00-05:00
# Position Size:-50
# Portfolio Value: 100025.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:02:00-05:00
# Position Size:-50
# Portfolio Value: 100020.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:03:00-05:00
# Position Size:-50
# Portfolio Value: 100043.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:04:00-05:00
# Position Size:-50
# Portfolio Value: 100046.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:05:00-05:00
# Position Size:-50
# Portfolio Value: 100052.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:06:00-05:00
# Position Size:-50
# Portfolio Value: 100040.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:07:00-05:00
# Position Size:-50
# Portfolio Value: 100040.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:08:00-05:00
# Position Size:-50
# Portfolio Value: 100057.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:09:00-05:00
# Position Size:-50
# Portfolio Value: 100042.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:10:00-05:00
# Position Size:-50
# Portfolio Value: 100032.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:11:00-05:00
# Position Size:-50
# Portfolio Value: 100051.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:12:00-05:00
# Position Size:-50
# Portfolio Value: 100047.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:13:00-05:00
# Position Size:-50
# Portfolio Value: 100041.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:14:00-05:00
# Position Size:-50
# Portfolio Value: 100039.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:15:00-05:00
# Position Size:-50
# Portfolio Value: 100045.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:16:00-05:00
# Position Size:-50
# Portfolio Value: 100038.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:17:00-05:00
# Position Size:-50
# Portfolio Value: 100029.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:18:00-05:00
# Position Size:-50
# Portfolio Value: 99994.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 0.0
# Time: 2022-12-13 15:19:00-05:00
# Position Size:-50
# Portfolio Value: 99989.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# delta Time is: 60.0
# checking double or nothing
# exit not double
# Placing sell order
# Deduct commission=1.0
# 2022-12-13 15:19:00-05:00 394 STK,,,SPY,USD BOT 50 401.39
# Time: 2022-12-13 15:20:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 15:21:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 15:22:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 15:23:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 15:24:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Time: 2022-12-13 15:25:00-05:00
# Position Size:0
# Portfolio Value: 99988.86000000002
# checking the cross
# checking to enter
# checking short
#
# checking long
#
# Checking Long before the chop
#
# macd and signal with delta, delta, 0.02, 0.020000000000000004, 0.1
# Placing Buy Order
# Deduct commission=1.0
# 2022-12-13 15:25:00-05:00 402 STK,,,SPY,USD BOT 50 401.62
# Time: 2022-12-13 15:26:00-05:00
# Position Size:50
# Portfolio Value: 99976.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:27:00-05:00
# Position Size:50
# Portfolio Value: 99985.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:28:00-05:00
# Position Size:50
# Portfolio Value: 99969.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:29:00-05:00
# Position Size:50
# Portfolio Value: 99984.86000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:30:00-05:00
# Position Size:50
# Portfolio Value: 99993.36000000002
# checking to Exit
# checking to sell short
#
# checking to sell long
#
# Time: 2022-12-13 15:31:00-05:00
# Position Size:50
# Portfolio Value: 100012.36000000002
# Time: 2022-12-13 15:32:00-05:00
# Position Size:50
# Portfolio Value: 100022.86000000002
# C:\Users\Lane Capital\anaconda3_rev1\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# Output\candlestick_2022-12-18
# DailyPlot2022-12-18_10.png
# DailyPlot2022-12-18_11.png
# DailyPlot2022-12-18_12.png
# DailyPlot2022-12-18_7.png
# DailyPlot2022-12-18_8.png
# DailyPlot2022-12-18_9.png
# DailyPlot2022-12-18_full.png
# Daily_Log_2022-12-18.csv
# Daily_Price_Data_2022-12-18.csv
# TraderLog_2022-12-18.txt
# C:\Users\Lane Capital\anaconda3_rev1\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# ##    ACCOUNT Balance  DU2628075  ##
# CASH=79906.86000000002
# portfolio_value=100022.86000000002
# positions_value=20116.0
# ##    POSITIONS DU2628075   ##
# Symbol Amount Cost_basis
# STK,,,SPY,USD 50 401.62
# ##    Order Status DU2628075   ##
# {ibpyOrderId=ib62 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=49 tif=DAY orderRef= limitPrice=405.79} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib74 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=406.13} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib126 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=49 tif=DAY orderRef= limitPrice=404.23} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib134 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=404.98} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib139 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=405.33} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib145 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=404.99} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib149 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=405.14} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib152 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=147 tif=DAY orderRef= limitPrice=404.93} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib158 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=49 tif=DAY orderRef= limitPrice=404.65} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib178 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=49 tif=DAY orderRef= limitPrice=402.75} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib189 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.31} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib218 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=400.68} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib259 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.42} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib279 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.65} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib299 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=400.84} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib306 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.38} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib352 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=402.78} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib363 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=402.4} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib369 status=Filled order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.49} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib394 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.39} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib402 status=Filled order={account=DU2628075 action=BUY orderType=LMT amount=50 tif=DAY orderRef= limitPrice=401.62} contract={STK,,,SPY,USD}}
# {ibpyOrderId=ib411 status=Submitted order={account=DU2628075 action=SELL orderType=LMT amount=50 tif=DAY orderRef= limitPrice=402.32} contract={STK,,,SPY,USD}}
# ##    END    ##
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\Lane Capital\anaconda3_rev1\lib\site-packages\IPython\core\interactiveshell.py:3445: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Make a plot to show the backtesting results
from tools.portfolio_sharpe_ratio import use_latest_backtest_balanceLog
use_latest_backtest_balanceLog()

# %%
import csv
import datetime
from dateutil import tz
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
import numpy as np
import os
import pandas as pd
import pytz
import sys
import time

def plotDailyCandleStickMacd(priceData, 
                 logData, 
                 emaList: list = ['fast', 'slow', "macd"],
                 saveFig: bool = False,
                 outPutFileName: str=r"C:\Users\Lane Capital\OneDrive\Desktop\repos\plots\TestCandle.png",
                 x = None):

    """This function takes in a historical input data dataframe, EMA dataframe from calcEMAVector 
    and plots the differnet EMAS against the price. Price is assumed to be the close price"""

    #create figure
    fig, (ax,ax1) = plt.subplots(2,figsize=(36,28),gridspec_kw={'height_ratios': [2, 1]})

    #define width of candlestick elements
    width = 0.0005
    width2 = 0.0001

    #define up and down priceData
    up = priceData[priceData.close>=priceData.open]
    down = priceData[priceData.close<priceData.open]
    log = logData.copy()
    if x!=None:
        # remove elements not in the x limit
        up = up[up.time>datetime.datetime.timestamp(x[0])]
        up = up[up.time<datetime.datetime.timestamp(x[1])]

        down = down[down.time>datetime.datetime.timestamp(x[0])]
        down = down[down.time<datetime.datetime.timestamp(x[1])]

        log = log[log.time>datetime.datetime.timestamp(x[0])]
        log = log[log.time<datetime.datetime.timestamp(x[1])]

    #define colors to use
    col1 = 'green'
    col2 = 'red'

    ax.plot(log.date,log.fast)
    ax.plot(log.date,log.slow)

    outArray=plotEntryStatus(log)
    ax1.plot(log.date,outArray)

    ax1.plot(log.date,log.macd)
    ax1.plot(log.date,log.signalLine)


    #plot up priceData
    ax.bar(up.date,up.close-up.open,width,bottom=up.open,color=col1)
    ax.bar(up.date,up.high-up.close,width2,bottom=up.close,color=col1)
    ax.bar(up.date,up.low-up.open,width2,bottom=up.open,color=col1)

    # #plot down priceData
    ax.bar(down.date,down.close-down.open,width,bottom=down.open,color=col2)
    ax.bar(down.date,down.high-down.open,width2,bottom=down.open,color=col2)
    ax.bar(down.date,down.low-down.close,width2,bottom=down.close,color=col2)
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M',tz=tz.gettz('America/New York')))


    # Turn grid on for both major and minor ticks and style minor slightly differently.
    ax.grid(which='major')
    ax.grid(which='minor', linewidth=0.25)
    ax.minorticks_on()
    if len(up!=0):
        ax.set_ylim(np.min([np.min(up.low),np.min(down.low)])-.05,np.max([np.max(up.high),np.max(down.high)])+.05)

    ax1.grid(which='major')
    ax1.grid(which='minor', linewidth=0.25)
    ax1.minorticks_on()
    ax1.set_ylim((-1.1,1.1))


    ax.set_xlabel("Time",fontsize=30)
    ax1.set_xlabel("Time",fontsize=30)
    ax.set_ylabel("Stock Price (USD)",fontsize=30)
    ax1.set_ylabel("Value (nd)",fontsize=30)
    ax.set_title("SPY Stock Price: "+str(datetime.date.today()),fontdict={'fontsize': 40})
    ax1.set_title("MacD/Signal Line Value",fontdict={'fontsize': 40})
    ax1.legend(["holding flag","macd","signal line"],fontsize=20)
    if x!=None:
        ax.set_xlim(x)
        ax1.set_xlim(x)
        
def plotEntryStatus(logData):
    """ This function takes in data from the daily log, cleans the short/long bool data, and 
    outputs an array displaying if were holding long, short, or nothing."""
    
    # copy data
    log=logData.copy()
    
    # clean up data
    log = Utils.fixBoolData(log)
    
    holdStatus = Utils.calcEntryStatus(log)
    
    return holdStatus

# %%
# Clear the run and run this to analyze backtest data

import os
os.chdir(r'C:\algo2')
# coding=utf-8
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import pytz
import datetime
from Utils import Utils
from IBridgePy.IbridgepyTools import symbol
from configuration import test_me
from data_provider_factory.data_loading_plan import HistIngestionPlan, Plan
import pandas as pd

import csv
import datetime
from dateutil import tz
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator, FormatStrFormatter, AutoMinorLocator
import numpy as np
import os
import pandas as pd
import pytz
import sys
import time

from trader_factory import build_active_IBridgePy_plus
from IBridgePy.IbridgepyTools import symbol

from Utils import Algos
from Utils import EnterExits
from Utils import IndicatorCalculations
from Utils import Orders
from Utils import Plotters
from Utils import Utils
from UnitTests import testutils


sim = build_active_IBridgePy_plus('DU2628075') # Build an active trader to get connected to Interactive Brokers 
dailyPriceData = sim.request_historical_data(symbol('SPY'), '1 min', '2 D')
dailyPriceData.to_csv(r"Log\Daily_Price_Data_"+str(datetime.date.today())+".csv")

logData, priceData = Utils.loadAndCleanData()

 #create figure
fig, (ax,ax1) = plt.subplots(2,figsize=(36,28),gridspec_kw={'height_ratios': [2, 1]})

#define width of candlestick elements
width = 50
width2 = 10

# #define up and down priceData
up = priceData[priceData.close>=priceData.open]
down = priceData[priceData.close<priceData.open]
log = logData.copy()

#define colors to use
col1 = 'green'
col2 = 'red'

ax.plot(log.time,log.fast)
ax.plot(log.time,log.slow)

outArray=plotEntryStatus(log)
ax1.plot(log.time,outArray)

ax1.plot(log.time,log.macd)
ax1.plot(log.time,log.signalLine)

ax.legend(["fast", "slow"])
#plot up priceData
ax.bar(up.time,up.close-up.open,width,bottom=up.open,color=col1)
ax.bar(up.time,up.high-up.close,width2,bottom=up.close,color=col1)
ax.bar(up.time,up.low-up.open,width2,bottom=up.open,color=col1)

# #plot down priceData
ax.bar(down.time,down.close-down.open,width,bottom=down.open,color=col2)
ax.bar(down.time,down.high-down.open,width2,bottom=down.open,color=col2)
ax.bar(down.time,down.low-down.close,width2,bottom=down.close,color=col2)

ax2=ax.twinx()

ax2.plot(log.time,log.positionSize)





N=0
minLim = (log.time.max()-log.time.min())*N+log.time.min()
maxLim = log.time.max()-(log.time.max()-log.time.min())*N

x=(minLim-5,maxLim+5)
# x=(1.668E9+781750,1.668E9+800000)
ax.set_xlim(x)
ax1.set_xlim(x)
# ax.set_ylim((393,398))
ax1.set_ylim((-0.8,0.7))

ax.grid(which='both')
ax1.grid(which='both')

ax.minorticks_on()
ax1.minorticks_on()

# %%
 #create figure
fig, (ax,ax1) = plt.subplots(2,figsize=(36,28),gridspec_kw={'height_ratios': [2, 1]})

#define width of candlestick elements
width = 1
width2 = .33

# #define up and down priceData
up = priceData[priceData.close>=priceData.open]
down = priceData[priceData.close<priceData.open]
log = logData.copy()

#define colors to use
col1 = 'green'
col2 = 'red'

ax.plot(log.index,log.fast)
ax.plot(log.index,log.slow)

outArray=plotEntryStatus(log)
ax1.plot(log.index,outArray)

ax1.plot(log.index,log.macd)
ax1.plot(log.index,log.signalLine)

ax.legend(["fast", "slow"])
#plot up priceData
ax.bar(up.index,up.close-up.open,width,bottom=up.open,color=col1)
ax.bar(up.index,up.high-up.close,width2,bottom=up.close,color=col1)
ax.bar(up.index,up.low-up.open,width2,bottom=up.open,color=col1)

# #plot down priceData
ax.bar(down.index,down.close-down.open,width,bottom=down.open,color=col2)
ax.bar(down.index,down.high-down.open,width2,bottom=down.open,color=col2)
ax.bar(down.index,down.low-down.close,width2,bottom=down.close,color=col2)

ax2=ax.twinx()

ax2.plot(log.index,log.positionSize)





N=0
minLim = (log.index.max()-log.index.min())*N+log.index.min()
maxLim = log.index.max()-(log.index.max()-log.index.min())*N

x=(minLim-5,maxLim+5)
# x=(1.668E9+781750,1.668E9+800000)
ax.set_xlim(x)
ax1.set_xlim(x)
# ax.set_ylim((393,398))
ax1.set_ylim((-0.8,0.7))

ax.grid(which='both')
ax1.grid(which='both')

ax.minorticks_on()
ax1.minorticks_on()

# %%
fig, ax2 = plt.subplots()
ax2.plot(up.time,up.open)
ax2.set(xlim=(1.668E9+780000,1.668E9+800000))

# %%
fig, ax = plt.subplots()
ax.bar(up.index,up.close-up.open,.5,bottom=up.open,color=col1)

# %%
up.index

# %%
buys=[]
sales=[]
for i in range(1,len(logData.positionSize.values)):
    if logData.positionSize.values[i]==0 and logData.positionSize.values[i-1]!=0:
        sales.append(i)
    if logData.positionSize.values[i]!=0 and logData.positionSize.values[i-1]==0:
        buys.append(i)
print(buys)
print(sales)

# %%
import os
os.chdir(r'C:\algo2')
# coding=utf-8
import datetime as dt
import matplotlib.pyplot as plt
import numpy as np
import pytz
import datetime
from Utils import Utils
from IBridgePy.IbridgepyTools import symbol
from configuration import test_me
from data_provider_factory.data_loading_plan import HistIngestionPlan, Plan
import pandas as pd

# %%
startTime = dt.datetime(2022,12,14,9,30,0)
endTime = dt.datetime(2022,12,14,16,0,0)

print(endTime.timestamp())
print(startTime)
